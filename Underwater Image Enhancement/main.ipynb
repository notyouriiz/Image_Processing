# %%
# Out:
# ...
# Resuming download from 87031808 bytes (577478243 bytes left)...
# Resuming download from https://www.kaggle.com/api/v1/datasets/download/larjeck/uieb-dataset-raw?dataset_version_number=1 (87031808/664510051) bytes left.
# 100%|██████████| 634M/634M [03:56<00:00, 2.44MB/s]
# Extracting files...
# Path to dataset files: C:\Users\lenovo\.cache\kagglehub\datasets\larjeck\uieb-dataset-raw\versions\1
